# %%
import pandas as pd

DATA_PATH = "metrics/fgs--playroom--num_buckets.csv"

# Change 'data.csv' to the path of your CSV file
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    51795
# 0  41498
# 1  75034
# 2  33346
# 3  36653
# 4  31548

# %%
# Compute statistics on the first numeric column
col = df.select_dtypes(include='number').columns[0]

print(f"Column: {col}")
print(f"  Min:    {df[col].min()}")
print(f"  Max:    {df[col].max()}")
print(f"  Median: {df[col].median()}")
print(f"  Mean:   {df[col].mean()}")
# Out:
# Column: 51795
#   Min:    20948
#   Max:    76713
#   Median: 39232.5
#   Mean:   42568.107142857145

# %%
import matplotlib.pyplot as plt

col = df.select_dtypes(include='number').columns[0]

plt.figure(figsize=(8, 5))
plt.hist(df[col].dropna(), bins='auto', edgecolor='black')
plt.xlabel('Buckets')
plt.ylabel('Frequency')
plt.title(f'Histogram of {col}')
plt.tight_layout()
plt.show()
