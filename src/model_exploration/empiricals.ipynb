# %%
import pandas as pd

DATA_PATH = "/home/kenneth/Documents/School_GitHub/metrics/fgs--playroom--num_rendered.csv"

# Change 'data.csv' to the path of your CSV file
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    1592850
# 0  1264915
# 1  2337524
# 2  1003489
# 3  1108883
# 4   944680

# %%
# Compute statistics on the first numeric column
col = df.select_dtypes(include='number').columns[0]

print(f"Column: {col}")
print(f"  Min:    {df[col].min()}")
print(f"  Max:    {df[col].max()}")
print(f"  Median: {df[col].median()}")
print(f"  Mean:   {df[col].mean()}")
# Out:
# Column: 1592850
#   Min:    607753
#   Max:    2390618
#   Median: 1190701.5
#   Mean:   1298257.5714285714

# %%
import matplotlib.pyplot as plt

col = df.select_dtypes(include='number').columns[0]

plt.figure(figsize=(8, 5))
plt.hist(df[col].dropna(), bins='auto', edgecolor='black')
plt.xlabel('Buckets')
plt.ylabel('Frequency')
plt.title(f'Histogram of {col}')
plt.tight_layout()
plt.show()
