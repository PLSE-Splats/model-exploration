# %%
import pandas as pd

DATA_PATH = "metrics/fgs--garden--n_processed.csv"

# Change 'data.csv' to the path of your CSV file
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    130
# 0  130
# 1  130
# 2  130
# 3  130
# 4  130

# %%
# Compute statistics on the first numeric column
col = df.select_dtypes(include='number').columns[0]

print(f"Column: {col}")
print(f"  Min:    {df[col].min():,}")
print(f"  Max:    {df[col].max():,}")
print(f"  Median: {df[col].median():,}")
print(f"  Mean:   {df[col].mean():,}")
# Out:
# Column: 130
#   Min:    2
#   Max:    6,441
#   Median: 474.0
#   Mean:   571.5192288415585

# %%
import matplotlib.pyplot as plt

col = df.select_dtypes(include='number').columns[0]

plt.figure(figsize=(8, 5))
plt.hist(df[col].dropna(), bins='auto', edgecolor='black')
plt.xlabel('Buckets')
plt.ylabel('Frequency')
plt.title(f'Histogram of {col}')
plt.tight_layout()
plt.show()
