# %%
import pandas as pd

DATA_PATH = "/home/kenneth/Documents/School_GitHub/metrics/fgs--garden--n_visible_primitives.csv"

# Change 'data.csv' to the path of your CSV file
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
#    1748151
# 0  1565273
# 1  1600141
# 2  1569363
# 3  1785817
# 4  1448971

# %%
# Compute statistics on the first numeric column
col = df.select_dtypes(include='number').columns[0]

print(f"Column: {col}")
print(f"  Min:    {df[col].min()}")
print(f"  Max:    {df[col].max()}")
print(f"  Median: {df[col].median()}")
print(f"  Mean:   {df[col].mean()}")
# Out:
# Column: 1748151
#   Min:    1258908
#   Max:    1785817
#   Median: 1438668.0
#   Mean:   1444051.9130434783

# %%
import matplotlib.pyplot as plt

col = df.select_dtypes(include='number').columns[0]

plt.figure(figsize=(8, 5))
plt.hist(df[col].dropna(), bins='auto', edgecolor='black')
plt.xlabel('Buckets')
plt.ylabel('Frequency')
plt.title(f'Histogram of {col}')
plt.tight_layout()
plt.show()
